# %%
from pathlib import Path 
import os, dotenv
dotenv.load_dotenv()
os.chdir(Path(os.getenv("PYTHONPATH")).expanduser())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json

# %%
from src.preprocessing.slice_cryptol_preprocess import process_sliced_files_to_df 
df = process_sliced_files_to_df(
        sliced_root="/Users/josh/SecurityAnalytics/toy-cryptol-ast/sliced_files_test",
        mount_dir=os.getenv("MOUNT_DIR"),
        server_url="http://localhost:8080",
    )
# Out:
# [pipeline] REPO_ROOT   : /Users/josh/SecurityAnalytics/DataPreprocess/cryptol-files
# [pipeline] SLICED_ROOT : /Users/josh/SecurityAnalytics/toy-cryptol-ast/sliced_files_test
# [pipeline] SERVER_URL  : http://localhost:8080
#
# [pipeline] Completed.
#   Total files seen   : 0
#   Initial load PASS  : 0
#   Initial load FAIL  : 0
#   Rows in DataFrame  : 0

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
