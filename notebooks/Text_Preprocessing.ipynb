# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# %%
from preprocessing.text_agent import get_or_process_text

text_df = pd.read_json("data/parsed_text_data.jsonl", lines=True)
text_df.head()
# Out:
#                                            filename filetype  \
# 0    https_saw.galois.com_intro_IntroToSAW.html.txt      txt
# 1      https_saw.galois.com_intro_Pointers.html.txt      txt
# 2       https_saw.galois.com_intro_Salsa20.html.txt      txt
# 3   https_saw.galois.com_intro_HMACProblem.html.txt      txt
# 4  https_saw.galois.com_intro_HMACSolution.html.txt      txt
#
#                                              content
# 0  First Example: Counting Set Bits\n\nMost devel...
# 1  Specifying Memory Layout\n\nPrograms are about...
# 2  Compositional Verification and Salsa20\n\nFirs...
# 3  Proof Maintenance Exercises: s2n HMAC\n\nThe e...
# 4  Proof Maintenance Exercises: Solutions\n\nThis...

# %%
load_dotenv()
OPEN_AI_KEY = os.getenv("OPEN_AI_KEY")

# %%
text_processing = []
i = 0
for _, row in text_df.iterrows():
    i += 1
    raw = row["content"]
    print(f"Processing row {i} / {len(text_df)}: {row['filename']}")
    result = get_or_process_text(raw, model="gpt-4.1-mini", key=OPEN_AI_KEY)
    if isinstance(result, tuple) and len(result) == 2:
        hash, processed = result
    else:
        hash, processed = None, result
    text_processing.append({
        "filename": row["filename"],
        "hash": hash,
        "input": row["content"],
        "processed": processed
    })
    row["content"] = processed
text_processing_df = pd.DataFrame(text_processing)
text_processing_df.head()
# Out:
# Processing row 1 / 30: https_saw.galois.com_intro_IntroToSAW.html.txt
# Processing row 2 / 30: https_saw.galois.com_intro_Pointers.html.txt
# Processing row 3 / 30: https_saw.galois.com_intro_Salsa20.html.txt
# Processing row 4 / 30: https_saw.galois.com_intro_HMACProblem.html.txt
# Processing row 5 / 30: https_saw.galois.com_intro_HMACSolution.html.txt
# Processing row 6 / 30: https_galoisinc.github.io_cryptol_master_BasicSyntax.html.txt
# Processing row 7 / 30: https_galoisinc.github.io_cryptol_master_Expressions.html.txt
# Processing row 8 / 30: https_galoisinc.github.io_cryptol_master_BasicTypes.html.txt
# Processing row 9 / 30: https_galoisinc.github.io_cryptol_master_OverloadedOperations.html.txt
# Processing row 10 / 30: https_galoisinc.github.io_cryptol_master_TypeDeclarations.html.txt
# Processing row 11 / 30: https_galoisinc.github.io_cryptol_master_Modules.html.txt
# Processing row 12 / 30: https_galoisinc.github.io_cryptol_master_FFI.html.txt
# Processing row 13 / 30: https_galoisinc.github.io_cryptol_master_Project.html.txt
# Processing row 14 / 30: https_galoisinc.github.io_cryptol_master_REPLCommands.html.txt
# Processing row 15 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_overview.html.txt
# Processing row 16 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_structure-of-sawscript.html.txt
# Processing row 17 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_invoking-saw.html.txt
# Processing row 18 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_cryptol-and-its-role-in-saw.html.txt
# Processing row 19 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_loading-code.html.txt
# Processing row 20 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_analyzing-hardware-circuits-using-yosys.html.txt
# Processing row 21 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_creating-symbolic-variables.html.txt
# Processing row 22 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_symbolic-execution.html.txt
# Processing row 23 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_symbolic-termination.html.txt
# Processing row 24 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_the-term-type.html.txt
# Processing row 25 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_specification-based-verification.html.txt
# Processing row 26 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_bisimulation-prover.html.txt
# Processing row 27 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_transforming-term-values.html.txt
# Processing row 28 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_proofs-about-terms.html.txt
# Processing row 29 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_extraction-to-the-coq-theorem-prover.html.txt
# Processing row 30 / 30: https_galoisinc.github.io_saw-script_master_saw-user-manual_formal-deprecation-process.html.txt
#                                            filename  \
# 0    https_saw.galois.com_intro_IntroToSAW.html.txt
# 1      https_saw.galois.com_intro_Pointers.html.txt
# 2       https_saw.galois.com_intro_Salsa20.html.txt
# 3   https_saw.galois.com_intro_HMACProblem.html.txt
# 4  https_saw.galois.com_intro_HMACSolution.html.txt
#
#                                                 hash  \
# 0  c1c0ea89741609032f2be284d23cdfbfa6a984fb42642b...
# 1  dc3e7d9ee52338bb41902d67a67e1e8ce7db549aebc5fd...
# 2  6ad48d3e7d1b0b4c60a585567246ec7ef960671963c177...
# 3  34b8dc6564472d2cb9f1cc2ab31939734f5ad17c3ac3e6...
# 4  7165c5da44ba90f705c2b3ec9a157ecfb058ea515bcc5d...
#
#                                                input  \
# 0  First Example: Counting Set Bits\n\nMost devel...
# 1  Specifying Memory Layout\n\nPrograms are about...
# 2  Compositional Verification and Salsa20\n\nFirs...
# 3  Proof Maintenance Exercises: s2n HMAC\n\nThe e...
# 4  Proof Maintenance Exercises: Solutions\n\nThis...
#
#                                            processed
# 0  ```markdown\n## First Example: Counting Set Bi...
# 1  ```markdown\n## Specifying Memory Layout\n\nPr...
# 2  ```markdown\n## Compositional Verification and...
# 3  ```markdown\n## Proof Maintenance Exercises: s...
# 4  ```markdown\n## Proof Maintenance Exercises: S...

# %%
text_df.head()
# Out:
#                                            filename filetype  \
# 0    https_saw.galois.com_intro_IntroToSAW.html.txt      txt
# 1      https_saw.galois.com_intro_Pointers.html.txt      txt
# 2       https_saw.galois.com_intro_Salsa20.html.txt      txt
# 3   https_saw.galois.com_intro_HMACProblem.html.txt      txt
# 4  https_saw.galois.com_intro_HMACSolution.html.txt      txt
#
#                                              content
# 0  ```markdown\n## First Example: Counting Set Bi...
# 1  ```markdown\n## Specifying Memory Layout\n\nPr...
# 2  ```markdown\n## Compositional Verification and...
# 3  ```markdown\n## Proof Maintenance Exercises: s...
# 4  ```markdown\n## Proof Maintenance Exercises: S...

# %%
text_df.to_json("data/training_datasets/cleaned_text_data.jsonl", lines=True, orient="records")
