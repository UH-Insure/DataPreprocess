# %%
from pathlib import Path 
import os, dotenv
dotenv.load_dotenv()
os.chdir(Path(os.getenv("PYTHONPATH")).expanduser())

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

# %%
from src.preprocessing.text_agent import get_or_process_text

text_df = pd.read_json("data/parsed_text_data.jsonl", lines=True)
text_df.head()
# Out:
#                                          filename filetype  \
# 0    https://saw.galois.com/intro/IntroToSAW.html      txt
# 1      https://saw.galois.com/intro/Pointers.html      txt
# 2       https://saw.galois.com/intro/Salsa20.html      txt
# 3   https://saw.galois.com/intro/HMACProblem.html      txt
# 4  https://saw.galois.com/intro/HMACSolution.html      txt
#
#                                              content
# 0  First Example: Counting Set Bits\n\nMost devel...
# 1  Specifying Memory Layout\n\nPrograms are about...
# 2  Compositional Verification and Salsa20\n\nFirs...
# 3  Proof Maintenance Exercises: s2n HMAC\n\nThe e...
# 4  Proof Maintenance Exercises: Solutions\n\nThis...

# %%
load_dotenv()
OPEN_AI_KEY = os.getenv("OPEN_AI_KEY")

# %%
exclusion_list = [
    "cryptol-specs/Primitive/Keyless/Hash/MD5.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Block/PRINCE.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Block/DES.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Block/LED.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Block/PRINCE.md"
    "cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/ChaChaPolyCryptolIETF.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/ChaChaPolyCryptolIETF.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/SIV_rfc5297.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC1_6_Tests.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Stream/Salsa20.md",
    "cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC1_6.md",
    "cryptol-specs/Primitive/Symmetric/KDF/HKDF.md",
    "cryptol-specs/Primitive/Symmetric/KDF/HKDF256Tests.md"
]

# %%
text_processing = []
i = 0
for _, row in text_df.iterrows():
    i += 1
    raw = row["content"]
    print(f"Processing row {i} / {len(text_df)}: {row['filename']}")
    if row["filename"] in exclusion_list:
        print(f"  Skipping excluded file: {row['filename']}")
        text_processing.append({
            "filename": row["filename"],
            "hash": None,
            "input": row["content"],
            "processed": raw
        })
        continue
    result = get_or_process_text(raw, model="gpt-4.1-mini", key=OPEN_AI_KEY)
    if isinstance(result, tuple) and len(result) == 2:
        hash, processed = result
    else:
        hash, processed = None, result
    text_processing.append({
        "filename": row["filename"],
        "hash": hash,
        "input": row["content"],
        "processed": processed
    })
    row["content"] = processed
text_processing_df = pd.DataFrame(text_processing)
text_processing_df.head()
# Out:
# Processing row 1 / 59: https://saw.galois.com/intro/IntroToSAW.html
# Processing row 2 / 59: https://saw.galois.com/intro/Pointers.html
# Processing row 3 / 59: https://saw.galois.com/intro/Salsa20.html
# Processing row 4 / 59: https://saw.galois.com/intro/HMACProblem.html
# Processing row 5 / 59: https://saw.galois.com/intro/HMACSolution.html
# Processing row 6 / 59: https://galoisinc.github.io/cryptol/master/BasicSyntax.html
# Processing row 7 / 59: https://galoisinc.github.io/cryptol/master/Expressions.html
# Processing row 8 / 59: https://galoisinc.github.io/cryptol/master/BasicTypes.html
# Processing row 9 / 59: https://galoisinc.github.io/cryptol/master/OverloadedOperations.html
# Processing row 10 / 59: https://galoisinc.github.io/cryptol/master/TypeDeclarations.html
# Processing row 11 / 59: https://galoisinc.github.io/cryptol/master/Modules.html
# Processing row 12 / 59: https://galoisinc.github.io/cryptol/master/FFI.html
# Processing row 13 / 59: https://galoisinc.github.io/cryptol/master/Project.html
# Processing row 14 / 59: https://galoisinc.github.io/cryptol/master/REPLCommands.html
# Processing row 15 / 59: https://weaversa.github.io/cryptol-course/labs/Overview/Overview.html
# Processing row 16 / 59: https://weaversa.github.io/cryptol-course/labs/Interpreter/Interpreter.html
# Processing row 17 / 59: https://weaversa.github.io/cryptol-course/labs/Language/Basics.html
# Processing row 18 / 59: https://weaversa.github.io/cryptol-course/labs/CRC/CRC.html
# Processing row 19 / 59: https://weaversa.github.io/cryptol-course/labs/Salsa20/Salsa20.html
# Processing row 20 / 59: https://weaversa.github.io/cryptol-course/labs/CryptoProofs/CryptoProofs.html
# Processing row 21 / 59: https://weaversa.github.io/cryptol-course/labs/KeyWrapping/KeyWrapping.html
# Processing row 22 / 59: https://www.galois.com/articles/cryptographic-assurance-with-cryptol
# Processing row 23 / 59: https://www.galois.com/articles/cryptol-saw-and-the-galois-origin-story
# Processing row 24 / 59: https://www.galois.com/articles/cryptol-saw-minilock
# Processing row 25 / 59: https://www.galois.com/articles/proving-program-equivalence-with-saw
# Processing row 26 / 59: https://www.galois.com/articles/solving-n-queens-in-cryptol
# Processing row 27 / 59: https://www.galois.com/articles/block-ciphers-homomorphically
# Processing row 28 / 59: https://www.galois.com/articles/a-cryptol-implementation-of-skein
# Processing row 29 / 59: https://pure.royalholloway.ac.uk/ws/portalfiles/portal/52628521/Accepted_Manuscript.pdf
# Processing row 30 / 59: https://assets.amazon.science/4e/23/177acd514c799204ae22f98e193d/verified-cryptographic-code-for-everybody.pdf
# Processing row 31 / 59: https://www.galois.com/articles/verifying-s2n-hmac-with-saw?utm_source=chatgpt.com
# Processing row 32 / 59: cryptol-specs/Primitive/Keyless/Hash/MD5.md
#   Skipping excluded file: cryptol-specs/Primitive/Keyless/Hash/MD5.md
# Processing row 33 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Block/TripleDES.md
# Processing row 34 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Block/DES.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Block/DES.md
# Processing row 35 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Block/LED.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Block/LED.md
# Processing row 36 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Block/PRINCE.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Block/PRINCE.md
# Processing row 37 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/ChaChaPolyCryptolIETF.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/ChaChaPolyCryptolIETF.md
# Processing row 38 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/SIV_rfc5297.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Authenticated/SIV_rfc5297.md
# Processing row 39 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC1_6_Tests.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC1_6_Tests.md
# Processing row 40 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Stream/Salsa20.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Stream/Salsa20.md
# Processing row 41 / 59: cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC1_6.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/Cipher/Stream/ZUC1_6.md
# Processing row 42 / 59: cryptol-specs/Primitive/Symmetric/KDF/HKDF.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/KDF/HKDF.md
# Processing row 43 / 59: cryptol-specs/Primitive/Symmetric/KDF/HKDF256Tests.md
#   Skipping excluded file: cryptol-specs/Primitive/Symmetric/KDF/HKDF256Tests.md
# Processing row 44 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/overview.html
# Processing row 45 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/structure-of-sawscript.html
# Processing row 46 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/invoking-saw.html
# Processing row 47 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/cryptol-and-its-role-in-saw.html
# Processing row 48 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/loading-code.html
# Processing row 49 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/analyzing-hardware-circuits-using-yosys.html
# Processing row 50 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/creating-symbolic-variables.html
# Processing row 51 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/symbolic-execution.html
# Processing row 52 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/symbolic-termination.html
# Processing row 53 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/the-term-type.html
# Processing row 54 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/specification-based-verification.html
# Processing row 55 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/bisimulation-prover.html
# Processing row 56 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/transforming-term-values.html
# Processing row 57 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/proofs-about-terms.html
# Processing row 58 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/extraction-to-the-coq-theorem-prover.html
# Processing row 59 / 59: https://galoisinc.github.io/saw-script/master/saw-user-manual/formal-deprecation-process.html
#                                          filename  \
# 0    https://saw.galois.com/intro/IntroToSAW.html
# 1      https://saw.galois.com/intro/Pointers.html
# 2       https://saw.galois.com/intro/Salsa20.html
# 3   https://saw.galois.com/intro/HMACProblem.html
# 4  https://saw.galois.com/intro/HMACSolution.html
#
#                                                 hash  \
# 0  c1c0ea89741609032f2be284d23cdfbfa6a984fb42642b...
# 1  dc3e7d9ee52338bb41902d67a67e1e8ce7db549aebc5fd...
# 2  6ad48d3e7d1b0b4c60a585567246ec7ef960671963c177...
# 3  34b8dc6564472d2cb9f1cc2ab31939734f5ad17c3ac3e6...
# 4  7165c5da44ba90f705c2b3ec9a157ecfb058ea515bcc5d...
#
#                                                input  \
# 0  First Example: Counting Set Bits\n\nMost devel...
# 1  Specifying Memory Layout\n\nPrograms are about...
# 2  Compositional Verification and Salsa20\n\nFirs...
# 3  Proof Maintenance Exercises: s2n HMAC\n\nThe e...
# 4  Proof Maintenance Exercises: Solutions\n\nThis...
#
#                                            processed
# 0  ```markdown\n## First Example: Counting Set Bi...
# 1  ```markdown\n## Specifying Memory Layout\n\nPr...
# 2  ```markdown\n## Compositional Verification and...
# 3  ```markdown\n## Proof Maintenance Exercises: s...
# 4  ```markdown\n## Proof Maintenance Exercises: S...

# %%
text_df.head()
# Out:
#                                          filename filetype  \
# 0    https://saw.galois.com/intro/IntroToSAW.html      txt
# 1      https://saw.galois.com/intro/Pointers.html      txt
# 2       https://saw.galois.com/intro/Salsa20.html      txt
# 3   https://saw.galois.com/intro/HMACProblem.html      txt
# 4  https://saw.galois.com/intro/HMACSolution.html      txt
#
#                                              content
# 0  ```markdown\n## First Example: Counting Set Bi...
# 1  ```markdown\n## Specifying Memory Layout\n\nPr...
# 2  ```markdown\n## Compositional Verification and...
# 3  ```markdown\n## Proof Maintenance Exercises: s...
# 4  ```markdown\n## Proof Maintenance Exercises: S...

# %%
text_df.to_json("data/training_datasets/cleaned_text_data.jsonl", lines=True, orient="records")
