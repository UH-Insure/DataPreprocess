# %%
import re
from pathlib import Path
from typing import Dict, List
import pandas as pd
from preprocessing.dependency_process import build_graph_from_df, coverage_report_from_df, extract_module_name, extract_type_defs

# %%
# Only match a *declaration* at line start:
#   module AES::Algorithm
# (The ^\s*module anchor guarantees we never pick up imports.)
MODULE_DECL_RE = re.compile(
    r"(?m)^\s*module\s+([A-Z][A-Za-z0-9_]*(?:::[A-Z][A-Za-z0-9_]*)*)\b"
)

def extract_declared_module(text: str) -> str | None:
    """Return the declared module name if the file has one, else None."""
    m = MODULE_DECL_RE.search(text or "")
    return m.group(1) if m else None

def build_module_index_from_df(
    df: pd.DataFrame,
    filename_col: str = "filename",
    content_col: str = "content",
) -> Dict[str, List[str]]:
    """
    Build {module_name: [filenames that declare it]} using only explicit module declarations.
    Files without a module declaration are simply *not* indexed.
    """
    index: Dict[str, List[str]] = {}
    for _, row in df.iterrows():
        fn = str(row[filename_col])
        mod = extract_declared_module(str(row[content_col]))
        if mod:
            index.setdefault(mod, []).append(fn)
    return index

# %%
all_df = pd.read_json("backup/data/cryptol_sources.jsonl", lines=True)

# %%
dropped_files = pd.read_csv("backup/data/dropped/dropped_files.csv")

# %%
dropped_files = dropped_files.merge(all_df[["filename", "content"]], on="filename", how="left")

# %%
dropped_files.head()
# Out:
#                        filename                                      sha1  \
# 0      cryptol/examples/AES.cry  1a40a5b760dce66cbee8b24a100c3da95850c5af
# 1    cryptol/examples/width.cry  6fcd12515c7bdf141d925f4c06dfa311b96c353d
# 2   cryptol/examples/Cipher.cry  0a59fbdcb5a178868f785173a719c45172e015e7
# 3      cryptol/examples/DES.cry  a04fb39b3596f8bd3aa2c68256cae565609d1666
# 4  cryptol/examples/DEStest.cry  f25dd313a807b5c1ee2a80e2e990ea5c0e4d9788
#
#    bytes  lines  avg_line_len  max_line_len  non_ascii_ratio  binary_like  \
# 0   8471    237         34.75            76              0.0        False
# 1     31      3          9.67            22              0.0        False
# 2    283     12         22.67            69              0.0        False
# 3   5435    172         30.60            69              0.0        False
# 4   9622    219         42.94            69              0.0        False
#
#    enc_total_matched  enc_max_run  ...  enc_hits_unicode  num_tokens_lang  \
# 0                  0            0  ...                 0             1969
# 1                  0            0  ...                 0               15
# 2                  0            0  ...                 0               37
# 3                  0            0  ...                 0             2367
# 4                  0            0  ...                 0             1309
#
#    k_shingle  num_shingles  hexnum_ratio  num_tokens_model  junk_path  \
# 0          5          1965      0.003047               NaN       True
# 1          5            11      0.000000               NaN       True
# 2          5            33      0.000000               NaN       True
# 3          5          2363      0.000000               NaN       True
# 4          5          1305      0.278075               NaN       True
#
#    quality_ok           fail_reason  \
# 0       False  similiar_file_exists
# 1       False   too_few_lang_tokens
# 2       False   too_few_lang_tokens
# 3       False  similiar_file_exists
# 4       False           hexnum_blob
#
#                                              content
# 0  // Cryptol AES Implementation\n// Copyright (c...
# 1                  x : [8]\nx = length (252 : [8])\n
# 2  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...
# 3  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...
# 4  /*\n * Copyright (c) 2013-2016 Galois, Inc.\n ...
#
# [5 rows x 23 columns]

# %%
training_df = pd.read_json("backup/data/training_datasets/verified_nocomments.jsonl", lines=True)

# %%
G, summary = build_graph_from_df(training_df)
#print(graph)

# %%
import matplotlib.pyplot as plt
import networkx as nx

plt.figure(figsize=(12, 8))
pos = nx.spring_layout(G, k=0.3, seed=42)
nx.draw(G, pos, with_labels=True, node_size=800, font_size=8, arrows=True)
edge_labels = nx.get_edge_attributes(G, "rel")
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=6)
plt.show()

# %%
def _coerce_for_xml(v):
    # Allowed: str, int, float, bool, None (becomes empty string)
    if v is None or v == "":
        return ""                      # GraphML can’t store None
    if isinstance(v, (str, int, float, bool)):
        return v
    if isinstance(v, (list, tuple, set)):
        return ",".join(map(str, v))   # or json.dumps(v)
    if isinstance(v, dict):
        return json.dumps(v, ensure_ascii=False)
    return str(v)                      # fallback for custom objects

def graphml_safe_copy(G):
    H = G.__class__()                  # preserve Graph/DiGraph/MultiGraph type
    H.graph = {str(k): _coerce_for_xml(v) for k, v in G.graph.items()}
    for n, d in G.nodes(data=True):
        H.add_node(n, **{str(k): _coerce_for_xml(v) for k, v in d.items()})
    if G.is_multigraph():
        for u, v, k, d in G.edges(keys=True, data=True):
            H.add_edge(u, v, key=k, **{str(k2): _coerce_for_xml(v2) for k2, v2 in d.items()})
    else:
        for u, v, d in G.edges(data=True):
            H.add_edge(u, v, **{str(k): _coerce_for_xml(v2) for k, v2 in d.items()})
    return H

# Use it:
H = graphml_safe_copy(G)
nx.write_graphml(H, "cryptol_dependency_graph.graphml")   # Cytoscape/Gephi
# or:
nx.write_gexf(H, "cryptol_dependency_graph.gexf")         # Best for Gephi

# %%
coverage = coverage_report_from_df(G=G, df=training_df)
print(f"{coverage["missing_modules_in_training"]}\n{len(coverage["missing_modules_in_training"])}")
# Out:
# ['AES::SubByteSBox', 'CfrgCurves', 'Cipher', 'Common::AES_GCM_SIV', 'Common::ByteArray', 'Common::EC::PrimeField::Instantiations::P192', 'Common::EC::PrimeField::Instantiations::P224', 'Common::EC::PrimeField::Instantiations::P256', 'DRBG', 'Field', 'Id', 'Poly1305', 'Primitive::Keyless::Hash::SHA2Internal::SHA256', 'Primitive::Keyless::Hash::SHA2Internal::SHA384', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_224', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_256', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_384', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_512', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHAKE256', 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES128', 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES192', 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES256', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_128', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_192', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_256', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck32_64', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck48_72', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck48_96', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck64_128', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck64_96', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck96_144', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck96_96', 'Primitive::Symmetric::Cipher::Block::TripleDES', 'Primitive::Symmetric::Cipher::Stream::Salsa20', 'Set', 'T012_M']
# 36

# %%
dropped_files_modules = []
for row in dropped_files.itertuples():
    modules = extract_module_name(row.content)
    if modules:
        dropped_files_modules.append({row.filename : modules})

# %%
missing_imports_from_dropped = [x for x in coverage["missing_modules_in_training"] if any(x in vals for d in dropped_files_modules for vals in d.values())]
missing_imports_not_found = [x for x in coverage["missing_modules_in_training"] if not any(x in vals for d in dropped_files_modules for vals in d.values())]

print(f"found: {missing_imports_from_dropped}\nlost: {missing_imports_not_found}")
# Out:
# found: ['AES::SubByteSBox', 'Cipher', 'Common::AES_GCM_SIV', 'Common::ByteArray', 'Common::EC::PrimeField::Instantiations::P192', 'Common::EC::PrimeField::Instantiations::P224', 'Common::EC::PrimeField::Instantiations::P256', 'DRBG', 'Field', 'Id', 'Primitive::Keyless::Hash::SHA2Internal::SHA256', 'Primitive::Keyless::Hash::SHA2Internal::SHA384', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_224', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_256', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_384', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_512', 'Primitive::Keyless::Hash::SHA3::Instantiations::SHAKE256', 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES128', 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES192', 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES256', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_128', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_192', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_256', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck32_64', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck48_72', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck48_96', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck64_128', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck64_96', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck96_144', 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck96_96', 'Set', 'T012_M']
# lost: ['CfrgCurves', 'Poly1305', 'Primitive::Symmetric::Cipher::Block::TripleDES', 'Primitive::Symmetric::Cipher::Stream::Salsa20']

# %%
files_to_put_back = []
for dict in dropped_files_modules:
    missing_found = [x for x in dict.values() if x in missing_imports_from_dropped]
    if len(missing_found) > 0:
        files_to_put_back.append(dict )

print(files_to_put_back)
with open("data/dropped/files_to_put_back.csv", "w") as f:
    f.write("filename,module\n")
    for d in files_to_put_back:
        for k, v in d.items():
            f.write(f"{k},{v}\n")
# Out:
# [{'cryptol/examples/Cipher.cry': 'Cipher'}, {'cryptol/tests/modsys/functors/T012_M.cry': 'T012_M'}, {'cryptol/examples/param_modules/Common/AES_GCM_SIV.cry': 'Common::AES_GCM_SIV'}, {'cryptol/examples/param_modules/AES/SubByteSBox.cry': 'AES::SubByteSBox'}, {'cryptol/cryptol-remote-api/python/tests/cryptol/test-files/Id.cry': 'Id'}, {'cryptol-specs/Common/ByteArray.cry': 'Common::ByteArray'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck48_96.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck48_96'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck32_64.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck32_64'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck128_128.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_128'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck64_96.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck64_96'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck128_256.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_256'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck96_144.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck96_144'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck64_128.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck64_128'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck96_96.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck96_96'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck48_72.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck48_72'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Instantiations/Speck128_192.cry': 'Primitive::Symmetric::Cipher::Block::Speck::Instantiations::Speck128_192'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Instantiations/AES128.cry': 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES128'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Instantiations/AES256.cry': 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES256'}, {'cryptol-specs/Primitive/Symmetric/Cipher/Block/AES/Instantiations/AES192.cry': 'Primitive::Symmetric::Cipher::Block::AES::Instantiations::AES192'}, {'cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA384.cry': 'Primitive::Keyless::Hash::SHA2Internal::SHA384'}, {'cryptol-specs/Primitive/Keyless/Hash/SHA2Internal/SHA256.cry': 'Primitive::Keyless::Hash::SHA2Internal::SHA256'}, {'cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHA3_512.cry': 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_512'}, {'cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHA3_384.cry': 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_384'}, {'cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHAKE256.cry': 'Primitive::Keyless::Hash::SHA3::Instantiations::SHAKE256'}, {'cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHA3_224.cry': 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_224'}, {'cryptol-specs/Primitive/Keyless/Hash/SHA3/Instantiations/SHA3_256.cry': 'Primitive::Keyless::Hash::SHA3::Instantiations::SHA3_256'}, {'cryptol-specs/Common/EC/PrimeField/Instantiations/P256.cry': 'Common::EC::PrimeField::Instantiations::P256'}, {'cryptol-specs/Common/EC/PrimeField/Instantiations/P192.cry': 'Common::EC::PrimeField::Instantiations::P192'}, {'cryptol-specs/Common/EC/PrimeField/Instantiations/P224.cry': 'Common::EC::PrimeField::Instantiations::P224'}, {'saw-script/examples/ecdsa/cryptol-spec/Field.cry': 'Field'}, {'saw-script/examples/ecdsa/cryptol-spec/Set.cry': 'Set'}, {'saw-script/deps/cryptol-specs/Common/ByteArray.cry': 'Common::ByteArray'}, {'saw-script/deps/cryptol-specs/Primitive/Symmetric/Cipher/Block/Speck/Insta ...

# %%
nocomments_deps = pd.read_json("data/training_datasets/syntax_check/nocomments.jsonl", lines=True)
files_with_missing_deps = []
for row in nocomments_deps.itertuples():
    missing = [x for x in row.file_deps if x in missing_imports_not_found]
    if len(missing) > 0:
        files_with_missing_deps.append(row.filename)

print(files_with_missing_deps)
# Out:
# ['cryptol/examples/MiniLock/prim/CryptoBox.cry', 'cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CBC.cry', 'cryptol-specs/Primitive/Symmetric/Cipher/Block/Modes/TDES_CFB.cry', 'saw-script/intTests/test_ffi_verify_salsa/salsa.cry']
