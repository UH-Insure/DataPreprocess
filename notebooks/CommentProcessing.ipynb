# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
from src.preprocessing.comment_process import normalize_blanklines, strip_cryptol_comments_all

# %%
jsonl_path = "data/training_datasets/verified_nomods.jsonl"

nomod_df = pd.read_json(jsonl_path, lines=True)

# %%
nomod_df.head()
# Out:
#                                filename filetype  \
# 0          cryptol/examples/splitAt.cry      cry
# 1               cryptol/examples/AE.cry      cry
# 2       cryptol/examples/xor_cipher.cry      cry
# 3       cryptol/examples/zero_weird.cry      cry
# 4  cryptol/examples/builtin_lifting.cry      cry
#
#                                              content
# 0  x = [1,2,3,4] : [_][8]\n\ny = (splitAt x) : ([...
# 1  // WORK IN PROGRESS\n\n/*\nImplementation of t...
# 2  encrypt : {a}(fin a) => [8] -> [a][8] -> [a][8...
# 3  x : {a}() => a -> [16]\nx v = zero v \n\nprope...
# 4  //builtins lift over tuples, seqs, and records...

# %%
nocomment_df = nomod_df.copy()
nocomment_df["content"] = nocomment_df["content"].apply(strip_cryptol_comments_all)
nocomment_df["content"] = nocomment_df["content"].apply(normalize_blanklines)

# %%
nocomment_df.head(20)
# Out:
#                                 filename filetype  \
# 0           cryptol/examples/splitAt.cry      cry
# 1                cryptol/examples/AE.cry      cry
# 2        cryptol/examples/xor_cipher.cry      cry
# 3        cryptol/examples/zero_weird.cry      cry
# 4   cryptol/examples/builtin_lifting.cry      cry
# 5           cryptol/examples/inflist.cry      cry
# 6         cryptol/examples/Karatsuba.cry      cry
# 7              cryptol/examples/comp.cry      cry
# 8              cryptol/examples/mini.cry      cry
# 9              cryptol/examples/Test.cry      cry
# 10      cryptol/examples/OptionUtils.cry      cry
# 11         cryptol/examples/builtins.cry      cry
# 12            cryptol/examples/props.cry      cry
# 13           cryptol/examples/demote.cry      cry
# 14           cryptol/examples/append.cry      cry
# 15            cryptol/examples/split.cry      cry
# 16                 cryptol/lib/Array.cry      cry
# 17                cryptol/lib/SuiteB.cry      cry
# 18                 cryptol/lib/Float.cry      cry
# 19               cryptol/lib/PrimeEC.cry      cry
#
#                                               content
# 0   x = [1,2,3,4] : [_][8]\n\ny = (splitAt x) : ([...
# 1   module AE where\n\nparameter\n  type A : *    ...
# 2   encrypt : {a}(fin a) => [8] -> [a][8] -> [a][8...
# 3   x : {a}() => a -> [16]\nx v = zero v \n\nprope...
# 4   x = [True,False]\ny = [False,True]\n\nproperty...
# 5   a = [1 ... ]\nb = [1,2 ... ]\nc = [1 .. 5]\nd ...
# 6   module Karatsuba where\n\nkmult : {limb,n} (fi...
# 7   x : [_]([2],[3],[3],[4])\nx = [(a,b,c,d) | a <...
# 8   id : [32] -> [32]\nid x = rec x\n  where rec k...
# 9   module Test where\nimport Cipher\n\nevktest : ...
# 10  module OptionUtils where\n\nisSome : {a} Optio...
# 11  t : [8]\nt = if True then 5 else 4 \nf : [8]\n...
# 12  x = [True, False]\ny = [False, True]\nz = x + ...
# 13  x : {a}(fin a) => [a] -> [(a*2)+3]\nx v = 0 + ...
# 14  x : [_][8]\nx = [1,2,3,4,5,19,12,38,5,3]\n\ny ...
# 15  x = [1,2,3,4] : [_][8]\n\ny = (split x) : [2][...
# 16  module Array where\n\nprimitive type Array : *...
# 17  module SuiteB where\n\ntype AES128 = 4\n\ntype...
# 18  module Float where\n\nprimitive type ValidFloa...
# 19  module PrimeEC where\n\ntype AffinePoint p =\n...

# %%
nocomment_df.tail(20)
# Out:
#                                               filename filetype  \
# 755       saw-script/deps/what4/what4/doc/bvdomain.cry      cry
# 756     saw-script/deps/what4/what4/doc/bitsdomain.cry      cry
# 757    saw-script/deps/what4/what4/doc/arithdomain.cry      cry
# 758  saw-script/doc/llvm-java-verification-with-saw...      saw
# 759  saw-script/doc/llvm-java-verification-with-saw...      saw
# 760  saw-script/doc/llvm-java-verification-with-saw...      saw
# 761  saw-script/doc/llvm-java-verification-with-saw...      cry
# 762  saw-script/doc/llvm-java-verification-with-saw...      saw
# 763  saw-script/doc/llvm-java-verification-with-saw...      saw
# 764  saw-script/doc/llvm-java-verification-with-saw...      cry
# 765  saw-script/doc/llvm-java-verification-with-saw...      saw
# 766  saw-script/doc/llvm-java-verification-with-saw...      cry
# 767  saw-script/doc/llvm-java-verification-with-saw...      saw
# 768  saw-script/doc/llvm-java-verification-with-saw...      cry
# 769  saw-script/doc/llvm-java-verification-with-saw...      saw
# 770  saw-script/doc/llvm-java-verification-with-saw...      saw
# 771  saw-script/doc/rust-verification-with-saw/code...      cry
# 772  saw-script/doc/rust-verification-with-saw/code...      cry
# 773  saw-script/otherTests/cryptol-saw-core/instanc...      cry
# 774  saw-script/otherTests/cryptol-saw-core/supercl...      cry
#
#                                                content
# 755  module bvdomain where\n\nimport arithdomain as...
# 756  module bitsdomain where\n\ntype Dom n = { loma...
# 757  module arithdomain where\n\nbit : {i, n} (fin ...
# 758  cls <- java_load_class "FFS";\nbc <- llvm_load...
# 759  let add_spec = do {\n    x <- jvm_fresh_var "x...
# 760  set_base 16;\n\nprint "Extracting reference te...
# 761  all : {n, a} (fin n) => (a -> Bit, [n]a) -> Bi...
# 762  java_ffs_ref <- read_aig "java_ffs_ref.aig";\n...
# 763  import "NQueens.cry";\n\nprint {{ nQueens [0,1...
# 764  module Cipher where\n\ntype Cipher KeySize Blo...
# 765  l <- llvm_load_module "double.bc";\ndouble_imp...
# 766  module DES where\n\nimport Cipher\n\nencrypt k...
# 767  import "dotprod.cry";\n\nlet alloc_init ty v =...
# 768  ffs_ref: [32] -> [32]\nffs_ref x = ixs!0 where...
# 769  import "DES.cry";\n\nprint "proving dec_enc......
# 770  import "ffs.cry";\nj <- java_load_class "FFS";...
# 771  module Salsa20Extras where\n\nimport Salsa20\n...
# 772  module Salsa20 where\n\nquarterround : [4][32]...
# 773  zeroBit : Bit\nzeroBit = zero\n\nzeroInteger :...
# 774  zeroRing : {a} (Ring a) => a\nzeroRing = zero\...

# %%
nocomment_df["variant"] = "without_comments"
nocomment_df.head()
# Out:
#                                filename filetype  \
# 0          cryptol/examples/splitAt.cry      cry
# 1               cryptol/examples/AE.cry      cry
# 2       cryptol/examples/xor_cipher.cry      cry
# 3       cryptol/examples/zero_weird.cry      cry
# 4  cryptol/examples/builtin_lifting.cry      cry
#
#                                              content           variant
# 0  x = [1,2,3,4] : [_][8]\n\ny = (splitAt x) : ([...  without_comments
# 1  module AE where\n\nparameter\n  type A : *    ...  without_comments
# 2  encrypt : {a}(fin a) => [8] -> [a][8] -> [a][8...  without_comments
# 3  x : {a}() => a -> [16]\nx v = zero v \n\nprope...  without_comments
# 4  x = [True,False]\ny = [False,True]\n\nproperty...  without_comments

# %%
nocomment_df.to_json("data/training_datasets/verified_nocomments.jsonl", orient="records", lines=True, force_ascii=False)

# %%
from preprocessing.comment_extractor import extract_strip_cry_comments
# Create Hybrid Dataset
DECISION_CACHE_PATH = "GPT_comment_decisions_cache.jsonl"
comment_rows = []
dataset_rows = []
for index, row in nomod_df.iterrows():

    if row.filetype == "cry" or True:
        comments, file_record_ = extract_strip_cry_comments(
            filename=row.filename,
            content=row.content,
            llm_model_name="gpt-oss:20b",
            decision_cache_path=DECISION_CACHE_PATH
        )
        comment_rows.extend(comments)
        file_record = {
            "filename": file_record_["filename"],
            "filetype": row.filetype,
            "content": file_record_["content"],
            "variant": "hybrid"
        }
    else:
        file_record = {
            "filename": row.filename,
            "filetype": row.filetype,
            "content": row.content,
            "variant": "hybrid"
        }
    dataset_rows.append(file_record)

comment_df = pd.DataFrame(comment_rows)
hybrid_df = pd.DataFrame(dataset_rows)

# %%
comment_df.head()
# Out:
#                   filename                                      sha1  \
# 0  cryptol/examples/AE.cry  5e86684a393aa148fd0a454958fa967d95065be8
# 1  cryptol/examples/AE.cry  259850075ed51d4fd666df2fe0a2063d600374ce
# 2  cryptol/examples/AE.cry  150ca06f0e9d2946cbce4dc93eae2277e1402f91
# 3  cryptol/examples/AE.cry  84c8479e2cda530b361b5d04e7c090204713d38e
# 4  cryptol/examples/AE.cry  d552c54a82a17f171563b8dd15d500d5212539b2
#
#                                              comment   keep  \
# 0                                // WORK IN PROGRESS  False
# 1  /*\nImplementation of the algorithms from the ...   True
# 2                                      // State type  False
# 3                                        // Key type  False
# 4                                      // Block size  False
#
#                                              snippet
# 0
# 1  module AE where\n\nparameter\n  type A : *    ...
# 2                               type K : *
# 3                               type n : #
# 4                               type p : #

# %%
hybrid_df.head()
# Out:
#                                filename filetype  \
# 0          cryptol/examples/splitAt.cry      cry
# 1               cryptol/examples/AE.cry      cry
# 2       cryptol/examples/xor_cipher.cry      cry
# 3       cryptol/examples/zero_weird.cry      cry
# 4  cryptol/examples/builtin_lifting.cry      cry
#
#                                              content variant
# 0  x = [1,2,3,4] : [_][8]\n\ny = (splitAt x) : ([...  hybrid
# 1  /*\nImplementation of the algorithms from the ...  hybrid
# 2  encrypt : {a}(fin a) => [8] -> [a][8] -> [a][8...  hybrid
# 3  x : {a}() => a -> [16]\nx v = zero v \n\nprope...  hybrid
# 4  //builtins lift over tuples, seqs, and records...  hybrid

# %%
HYBRID_PATH = "data/training_datasets/GPTverified_hybrid.jsonl"
COMMENT_STAT_PATH = "data/GPTcomment_stats.jsonl"

hybrid_df.to_json(HYBRID_PATH, lines=True, orient="records")
comment_df.to_json(COMMENT_STAT_PATH, lines=True, orient="records")
